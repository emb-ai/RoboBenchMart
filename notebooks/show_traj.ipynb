# %%
import h5py
import matplotlib.pyplot as plt

# %%
f = h5py.File('../demo_envs/MoveFromBoardToBoardStaticEnv/demos/motionplanning/20250422_020746.h5', 'r')

# %%
f.keys()

# %%
f['traj_0'].keys()

# %%
f['traj_0']['obs'].keys()

# %%
bytes(list(f['traj_0']['obs']['extra']['language_instruction_bytes'][0])).decode()

# %%
f['traj_0']['obs']['sensor_data'].keys()

# %%
img = f['traj_1']['obs']['sensor_data']['fetch_hand']['rgb'][0]

# %%
plt.imshow(img)

# %%
img.shape
